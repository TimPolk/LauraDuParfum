# %%
from src.eda import plot_top_binary_columns
import pandas as pd

path = "./Data/fragrance_cleaned.csv"
df = pd.read_csv(path)
df.head()
plot_top_binary_columns(df, "john")
plot_top_binary_columns(df, "accord_")
plot_top_binary_columns(df, "NOTE_")
# Out:
# john
# ERROR: Choose either 'note_' or 'accord_'
# accord_
# note_

# %%
plot_top_binary_columns(df, "john")

# %%
plot_top_binary_columns(df, "ACCORD_")
plot_top_binary_columns(df, "NOTE_")
